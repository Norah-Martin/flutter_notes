# %% [markdown]
# <a href="https://colab.research.google.com/github/Norah-Martin/flutter_notes/blob/main/flutter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A shown in the below screen
# **home** where all your homescreen items will be visible
# and **text** part where all  your next will be shown:
#
# `void main()  => runApp(const MaterialApp( home: Text("hey!! "),)); //material app`

# %% [markdown]
# **Scaffold**
# To design visual layout structure
#
#
# ```
#  home: Scaffold(
#       appBar: AppBar(
#             title: Text('My First App'),
#             centerTitle: true, //centralised
#       ) ,
#           body: Center(
#                 child:  Text("hello!!"),
#           ),
#           floatingActionButton: FloatingActionButton(
#                 onPressed: () {  },
#                 child: Text('click'),
#           ),
# ),
# )); //material app
#
# ```
# ![f4.png](data:image/png;base64,...)

# %% [markdown]
# to make **Background Color**
#
# under the "AppBar"
#
# ```
#  backgroundColor:Colors.red[600] ,//[different strength ctrl+q]
# ```
# for floatingactionbutton same command under it
#
# color pallette of flutter is
#
# ![colorpallete.png](data:image/png;base64,...)

# %% [markdown]
# to custom the font:
#
# 1.   goto google fonts [link ](https://www.google.com/search?q=google+fonts&rlz=1C1YTUH_enIN1052IN1052&oq=g&aqs=chrome.0.69i59l2j69i64j69i57j69i60l4.1330j0j7&sourceid=chrome&ie=UTF-8)
# 2.   select the font say "Indie Flower"
# 3.  download it and extract it to the folder
# 4. then to add to our project
#
#       *   first edit the **"pubspec.yaml"**
#       *   Indentation very inmportant,goto to the font and make changes as shown below
#       * then in main project you will get the notification ,click "get dependecies"
# 5. add it under the TextStyle( )
#
#
# ![fontedit.png](data:image/png;base64,...)

# %% [markdown]
# ```
#  style: TextStyle(
#                     fontSize: 20.0,
#                     fontWeight: FontWeight.bold,
#                     letterSpacing: 2.0,
#                     color: Colors.grey[600],
#                     fontFamily: 'IndieFlower',
#                   ),
# ```
#
# ![f6.png](data:image/png;base64,...)

# %% [markdown]
# ![f5.png](data:image/png;base64,...)

# %% [markdown]
# **stateless widgets**
#
# -state of the widget cannot change over time
#
# -help with reload
#
# **stateful widgets**
#
# -state of the widget can change over time
#
#
# stateless widget
#
#
# ```
# class Home extends StatelessWidget {
#   @override
#   Widget build(BuildContext context) {
#     return Scaffold(
#     );
# ```
#
# to add image from local url
#
#
# 1.   edit the pubspec.yaml
# 2.   edit the assets
#
#
# ```
#   body: Center(
#         child: Image(
#           image:AssetImage('assets/pic2.jpg'),
#         )
#
# ```
# ![imageadd.png](data:image/png;base64,...)

# %% [markdown]
# ![f7.png](data:image/png;base64,...)

# %% [markdown]
# to add icons:
#
#
# ```
#      child:Icon(
#           Icons.lightbulb_outline,
#           color:  Colors.lightBlue,
#           size:100.0
#         )
# ```

# %% [markdown]
# to add elevated button
#
#
# ```
#       child: Text(
#           'click me',
#           style: TextStyle(
#           fontSize: 20.0,
#           fontWeight: FontWeight.bold,
#           letterSpacing: 2.0,
#           color: Colors.grey[600],
#           fontFamily: 'IndieFlower',
#         ),
#         ),
#       ),
#     ),
#
# ```
# ![f8.png](data:image/png;base64,...)

# %% [markdown]
# use of onPressed (){}
#
#
#
# ```
#   child: ElevatedButton(
#         onPressed: () {
#           print('you clicked!');
#         },
# ```
# when you click on the button this will be displayed:
#
# ```
# I/flutter (  448): you clicked!
# I/flutter (  448): you clicked!
# ```

# %% [markdown]
# to add icon to the elevated button:
#
#
#
# ```
#     body: Center(
#       child: ElevatedButton.icon(
#         onPressed: () {},
#         icon:Icon(
#           Icons.mail
#         ),
#               label:Text('mail me'),
#            //   color:Colors.amberAccent
# ```
#
# icon:
#
#
# ```
#  body: Center(
#       child: IconButton(
#         onPressed: () {
#           print('you clicked me');
#         },
#         icon:Icon(Icons.alternate_email),
#         color:Colors.amberAccent
#       )
# ```
# when you press the icon:
#
#
#
# ```
# I/flutter (  448): you clicked me
# I/flutter (  448): you clicked me
# I/flutter (  448): you clicked me
#
# ```

# %% [markdown]
# **container and padding**
#
#
#
# ```
#      body:Container(
#             padding:EdgeInsets.symmetric(horizontal: 30.0,vertical: 10.0) ,
#             color: Colors.blueGrey,
#               child: Text('hello;'),
#
#           ),
# ```
# or
#
#
#
# ```
#    padding:EdgeInsets.fromLTRB(10.0, 20.0, 30.0, 40.0)
# ```
