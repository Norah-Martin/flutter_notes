# %% [markdown]
# <a href="https://colab.research.google.com/github/Norah-Martin/flutter_notes/blob/main/flutter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#FLUTTER-mobile UI -iOS and Andrioid
#sigle code base -dart

# %% [markdown]
# **why flutter**
#
#
# 1.   1 code base
# 2.   good layout methodology
# 3.   smooth and quick
# 4.   well with Firebase as backend
# 5.   dart easy language
# 6.   design out of box

# %% [markdown]
# dart have:
#
#
# *   Classes
# *   Fuctions and Methods
# *    Variables
# *   Aynchronous code

# %% [markdown]
#  ***INSTALL***
#
# *   [andriodstudio](https://developer.android.com/studio)
# *   [git link ](https://git-scm.com/downloads)(imp)
# * [flutter](https://flutter.dev/docs/get-started/...)
#   *   load the git
#   * go to command prompt ,take the directory
#  * clone the flutter
#  * after go to flutter and view flutter console (shown below)
#  ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **WIDGETS**
#
# *   Root widget
#       *   app bar widget
#            * text widget
#       * container widget
#            * text widget
#
#
# button/row/column/image widget...
#    style,
#    text align,
#    color,
#    elevation....(customisable)
#
# go to DartPad
# [dart](https://dartpad.dartlang.org/?)
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# open android studio

# %% [markdown]
# after opening andriod studio open it and intsall **flutter**
#
# 1.   create new flutter project ,say myapp or first
# 2.   add a new
#
# ![fluuter1.png](data:image/png;base64,...)

# %% [markdown]
# ![flutter2.png](data:image/png;base64,...)
