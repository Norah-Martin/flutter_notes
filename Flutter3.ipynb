# %% [markdown]
# <a href="https://colab.research.google.com/github/Norah-Martin/flutter_notes/blob/main/Flutter3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Rows**
#
# to put more than 1 widget on a page by using rows (the Row widget!).
#
#
#
# ```
#  body:Row(
#       children: [
#         Text('Hello world'),
#         ElevatedButton(
#             onPressed: () {},
#             child:Text("click me!") ,
#         ),
#        Container(
#          color: Colors.cyan,
#          padding:EdgeInsets.all(30.0),
#            child:Text('Inside container')
#        )
#       ],
#     ),
# ```
#
# ![f10.png](data:image/png;base64,...)

# %% [markdown]
# Main Axis---->
#
# Cross Axis |
#
#
# ```
#  body:Row(
#       mainAxisAlignment: MainAxisAlignment.center,
#       crossAxisAlignment: CrossAxisAlignment.center,
#       children: [
# ```

# %% [markdown]
# **Column**
#
#
# ```
# body:Column(
#       children: [
#         Container(
#           padding: EdgeInsets.all(20.0),
#             color: Colors.cyan,
#             child:Text("one"),
#         ),
#         Container(
#           padding: EdgeInsets.all(30.0),
#           color: Colors.red,
#           child:Text("two"),
#         ),
#         Container(
#           padding: EdgeInsets.all(40.0),
#           color: Colors.yellow,
#           child:Text("three"),
#         ),
#       ],
#     ),
# ```
#
# ![f11.png](data:image/png;base64,...)

# %% [markdown]
# Main Axis |
# Cross Axis--->
#
#
#
# ```
#  mainAxisAlignment: MainAxisAlignment.end,
#       crossAxisAlignment: CrossAxisAlignment.center,
# ```
#
# Inside a row ,column inserted
#
#
# ```
#  body:Column(
#       mainAxisAlignment: MainAxisAlignment.end,
#       crossAxisAlignment: CrossAxisAlignment.stretch,
#       children: [
#         Row(
#           mainAxisAlignment: MainAxisAlignment.spaceAround,
#           crossAxisAlignment: CrossAxisAlignment.center,
#           children: [
#
#             Text('Most Used Services'),
#             ElevatedButton(
#               onPressed: () {},
#               child:Text("Plumbing") ,
#             ),
#             Container(
#                 color: Colors.amberAccent,
#                 padding:EdgeInsets.all(30.0),
#                 child:Text('Electrician')
#             )
#           ],
#         ),
#
#         Container(
#           padding: EdgeInsets.all(20.0),
#             color: Colors.cyan,
#             child:Text("one"),
#         ),
#         Container(
#           padding: EdgeInsets.all(30.0),
#           color: Colors.red,
#           child:Text("two"),
#         ),
#         Container(
#           padding: EdgeInsets.all(40.0),
#           color: Colors.yellow,
#           child:Text("three"),
#         ),
#       ],
#     ),
#
# ```
# ![f12.png](data:image/png;base64,...)

# %% [markdown]
# **Flutter Outline & Shortcuts**
#
# select the text -->yellow bulb on the left -->drag menu
#
# ![f13.png](data:image/png;base64,...)

# %% [markdown]
# ```
#  Padding(
#               padding: const EdgeInsets.all(30.0),
#               child: Container(
#                   color: Colors.amberAccent,
#                   padding:EdgeInsets.all(30.0),
#                   child:Text('Electrician')
#               ),
#             )
# ```

# %% [markdown]
# **Stateful Widget**
#
#
#
# ```
# class Test extends StatefulWidget {
#   @override
#   State<Test> createState() => _TestState();
# }
#
# class _TestState extends State<Test> {
#   @override
#   Widget build(BuildContext context) {
#     return Container();
#   }
# }
#
#
# ```
#
#
# setstate()
#
#
# ```
#  setState(() {
#       counter++;
#     });
#   }
# ```

# %% [markdown]
# **List**
#
# method 1:
#
#
# ```
# class _QuotelistState extends State<Quotelist> {
#   List<String> quotes=[
#     "hi",
#     "how",
#     "home"
#   ];
#
#
#   @override
#
# ```
# ```
#    body: Column(
#         children: quotes.map((quote)=> Text(quote)).toList(),
# ```
# In lib file make new dart file and add class:
#
#
#
# ```
# class Quote {
#
#    late String text ;
#   late String author;
#   Quote({required String text, required String author }) {
#     this.text = text;
#     this.author = author;
#   }
# }
#
# Quote myquote = Quote(text:"text:hi",author: "author:norah");
# ```

# %% [markdown]
# ![f14.png](data:image/png;base64,...)

# %% [markdown]
# **Cards**
#
#
# ```
#  Widget quoteTemplate(quote){
#     return Card(
#       margin: EdgeInsets.fromLTRB(16.0, 16.0, 16.0, 0),
#       child:Padding(
#         padding: const EdgeInsets.all(12.0),
#
#       child:Column(
#         crossAxisAlignment:CrossAxisAlignment.stretch ,
#         children: [
#           Text(
#             quote.text,
#             style: TextStyle(
#               fontSize: 18.0,
#               color: Colors.grey[600],
#             ),
#           ),
#           SizedBox(height: 6.0),
#
#         ],
#       ),
#       ),
#     );
#
#  }
#
#
#
#   children: quotes.map((quote)=> quoteTemplate(quote)).toList(),
#
# ```
#
# **Extracting Widget**

# %% [markdown]
# **multiple screens**
#
# 1.   take new flutter project,delete test
# 2.   in lib add packages,say pages
#
#            *   inside pages,add 3  dartfiles say:
#            *   home.dart
#            *   location.dart
#            *  loading.dart
#
# 3.  then in main.dart
#
#
# ```
# import 'package:flutter/material.dart';
# import 'package:joboy4/pages/home.dart';
#
#
# void main()  => runApp(MaterialApp(
#   home:joboy(),
# ));
#
#
# ```
#
# 4. all other dart files intiate the import files .
#
# now for loaction we need to study **ROUTING**
#
# Maps in Dart
#
#
# ```
# void main() {
#
#   Map student = {'name': 'norah','age':21};
#   print(student['name']) ; //norah
# }
#
#
# ```

# %% [markdown]
# **Widget Lifecycle**
#
#
#
# 1. Creation
# 2. Initialization: => createState()
# 3.  Mounted: => initState()
# 4.  Disposal => dispose()
# ...

# %% [markdown]
# **Asynchronous code**
#
#
#
# ```
# class _ChooseLocationState extends State<ChooseLocation> {
#
#   void getData()  async {
#     //simulate network request
#     Future.delayed(Duration(seconds: 2),(){
#     print('wait');
#     });
#
#     //simulate network request
#     Future.delayed(Duration(seconds: 2),(){
#       print('halo');
#     });
#     print("delayed");
#   }
#   @override
#   void initState() {
#     super.initState();
#     getData();
#
#   }
# ```
# ![f15.png](data:image/png;base64,...)

# %% [markdown]
# await
# ```
#   String user=await Future.delayed(Duration(seconds: 2),(){
#     return('wait');
#
#
#
#     print('$user');
# ```
#
# **flutter packages**
#
# http-3rd party api
#
# take it from packages
#
# edit pubspec and get dependecies

# %% [markdown]
# **loading.dart**
#
#
#
# ```
# void getData()  async {
#     Response response=await get('https://jsonplaceholder.typicode.com/todos/1' as Uri);
#     Map data =jsonDecode(response.body);
#     print(data);
#
#   }
#   @override
#   void initState() {
#   super.initState();
#   getData();
#
#   }
#
# ```
#
# ```
#
#  void getData()  async {
#     Response response=await get('https://jsonplaceholder.typicode.com/todos/1' as Uri);
#
#     Map data =jsonDecode(response.body);
#   // print(data);
#   String datetime = data['datetime'];
#   String offset= data['offset'];
# //print(datetime);
# //print(offset);
#
#   DateTime now = DateTime.parse(datetime);
#   now = now.add(Duration(hours:int.parse()));
#   print(now)
#
# }override
#   void initState() {
#   super.initState();
#   getData();
#
#   }
#
# ```
